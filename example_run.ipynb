# %%
# !python stack_sample.py
# Out:
# Loaded pairs: 5
# Final shapes: (5, 128, 128, 128) (5, 128, 128, 128)
# Saved:
#   ./Dataset/quijote128_z0_train_5.npy -> (5, 128, 128, 128) float32
#   ./Dataset/quijote128_z127_train_5.npy -> (5, 128, 128, 128) float32

# %%
# !python train.py
# Out:
# 🔍 Number of GPUs available: 1
# ✅ Total parameters: 5,359,457
# ✅ Trainable parameters: 5,359,425
# input_data shape: (5, 128, 128, 128)
# label_data shape: (5, 128, 128, 128)

# %%
# !python make_obs.py
# Out:
# ✅ Saved observation and truth for sim 9 to /scratch/dye7jx/Projects/ICdiffusion/run/cosmo1999_test

# %%
# !python sample.py 0 cosmo1999_test
# Out:
# Loaded shape: (1, 128, 128, 128)
# WARNING:root:Loaded checkpoint from run/checkpoints_5_128/checkpoint.pth.
# input_data shape before tiling: torch.Size([1, 1, 128, 128, 128])
# Sampling begins.
# ...
#  18%|███████▎                                | 182/1000 [00:44<03:11,  4.26it/s]

# %%
# !python Combine_sample.py
# Out:
# ✅ Final reshaped sample saved to: /scratch/dye7jx/Projects/ICdiffusion/run/cosmo1999_test/sample.npy
# ✅ New shape: (10, 128, 128, 128)

# %%
! /home/dye7jx/miniconda3/envs/nbodykit38/bin/python results.py cosmo1999_test
# Out:
# /home/dye7jx/miniconda3/envs/nbodykit38/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# INFO - ==== Data Statistics Check ====
# INFO - truth:
#   min: -4.394271
#   max: 5.6531878
#   mean: 3.0413503e-09
#   std: 0.9999999
# INFO - observation:
#   min: -1.2187482315335512
#   max: 34.4124997031293
#   mean: 1.4877928717189307e-05
#   std: 0.8207087075250817
# INFO - samples (all combined):
#   min: -1877.7615
#   max: 1701.3616
#   mean: 0.8686145
#   std: 329.24756
# INFO - ================================
# results_v1.py:149: RuntimeWarning: Mean of empty slice
#   mean_corr = np.nanmean(corr_coefs, axis=0)
# /home/dye7jx/miniconda3/envs/nbodykit38/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
# ...
